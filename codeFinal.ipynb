# %%
import csv
import pandas as pd

# %% [markdown]
# Findind Outlier Data

# %%
datafile = pd.read_csv('./datafile.csv')

# %%
datafile.columns
# Out:
# Index(['order_id', 'shop_id', 'user_id', 'order_amount', 'total_items',
#        'payment_method', 'created_at'],
#       dtype='object')

# %%
#checking the AOV mean calculation
datafile["order_amount"].mean()
# Out:
# 3145.128

# %%
datafile.head(5)
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11

# %%
#sorting the data by highest order_amount
df_sorted = datafile.sort_values(["order_amount"], ascending=False).head(100)

#df_sorted

# %%
#sorting the data more indepth to get see outlier data
outlier_data = df_sorted.loc[(df_sorted["order_amount"] > 1760) & (df_sorted["total_items"] >= 1)]
pd.set_option('display.max_rows', 500)
outlier_data.sort_values(["order_amount"], ascending=False).head(500)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 2153      2154       42      607        704000         2000    credit_card
# 3332      3333       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 4868      4869       42      607        704000         2000    credit_card
# 2969      2970       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 15          16       42      607        704000         2000    credit_card
# 4056      4057       42      607        704000         2000    credit_card
# 4882      4883       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# ...

# %% [markdown]
# Using different Metric calculation

# %%
datafile["order_amount"].median()
# Out:
# 284.0

# %%
df_copy = datafile.copy()

# %%
updated_df = df_copy.drop(df_copy[df_copy["order_amount"] >= 25725].index)

#updated_df.sort_values(["order_amount"], ascending=False).head(500)

# %%
updated_df.mean()
# Out:
# order_id        2499.551347
# shop_id           49.846465
# user_id          849.752279
# order_amount     302.580514
# total_items        1.994734
# dtype: float64
